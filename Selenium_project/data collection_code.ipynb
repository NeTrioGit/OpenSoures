# %%
import urllib
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# Chrome driver service 설정
chrome_service = Service('/Users/neo/GitHub/OpenSoures/Selenium_project/chromedriver')

# Chrome webdriver 생성
driver = webdriver.Chrome(service=chrome_service)

driver.get("https://www.google.co.kr/imghp?hl=ko&tab=wi&authuser=0&ogbl")
elem = driver.find_element(By.NAME, "q")
elem.send_keys("캔버스화")
elem.send_keys(Keys.RETURN)

os.makedirs('/Users/neo/GitHub/OpenSoures/Selenium_project/캔버스화', exist_ok=True)

SCROLL_PAUSE_TIME = 1
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)
    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_height = new_height

images = driver.find_elements(By.CSS_SELECTOR, ".rg_i.Q4LuWd")

count = 1

for image in images:
    try:
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element(By.CSS_SELECTOR, '.n3VNCb').get_attribute('src')
        urllib.request.urlretrieve(imgUrl, '/Users/neo/GitHub/OpenSoures/Selenium_project/캔버스화'+ str(count) + ".jpg")
        count += 1
#    except Exception as e:
#        print(f'Error occurred while downloading image {count}: {e}')
#        driver.quit()

#for image in images:
#    try:
#        image.click()
#        time.sleep(2)
#        imgUrl = driver.find_element_by_css_selector('.n3VNCb img').get_attribute('src')#

        # Set user-agent header for the request
#        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 Edg/94.0.992.38'}

        # Download the image
#        response = requests.get(imgUrl, headers=headers)

        # Save the image to a file
#        with open(f'/Users/neo/GitHub/OpenSoures/부자/{count}.jpg', 'wb') as f:
#            f.write(response.content)
#        count += 1
    except:
        pass
    
driver.quit()

# %%
import urllib
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# Chrome driver service 설정
chrome_service = Service('/Users/neo/GitHub/OpenSoures/Selenium_project/chromedriver')

# Chrome webdriver 생성
driver = webdriver.Chrome(service=chrome_service)

driver.get("https://www.google.co.kr/imghp?hl=ko&tab=wi&authuser=0&ogbl")
elem = driver.find_element(By.NAME, "q")
elem.send_keys("운동화")
elem.send_keys(Keys.RETURN)

os.makedirs('/Users/neo/GitHub/OpenSoures/Selenium_project/운동화', exist_ok=True)

SCROLL_PAUSE_TIME = 1
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)
    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_height = new_height

images = driver.find_elements(By.CSS_SELECTOR, ".rg_i.Q4LuWd")

count = 1

for image in images:
    try:
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element(By.CSS_SELECTOR, '.n3VNCb').get_attribute('src')
        urllib.request.urlretrieve(imgUrl, '/Users/neo/GitHub/OpenSoures/Selenium_project/'+ str(count) + ".jpg")
        count += 1
    except Exception as e:
        print(f'Error occurred while downloading image {count}: {e}')
        driver.quit()

#for image in images:
#    try:
#        image.click()
#        time.sleep(2)
#        imgUrl = driver.find_element_by_css_selector('.n3VNCb img').get_attribute('src')#

        # Set user-agent header for the request
#        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 Edg/94.0.992.38'}

        # Download the image
#        response = requests.get(imgUrl, headers=headers)

        # Save the image to a file
#        with open(f'/Users/neo/GitHub/OpenSoures/부자/{count}.jpg', 'wb') as f:
#            f.write(response.content)
#        count += 1
#    except:
#        pass
# Out:
# Error occurred while downloading image 33: Message: element not interactable
#   (Session info: chrome=111.0.5563.64)
# Stacktrace:
# 0   chromedriver                        0x0000000104de6d3c chromedriver + 4222268
# 1   chromedriver                        0x0000000104d6d8e8 chromedriver + 3725544
# 2   chromedriver                        0x0000000104a23c28 chromedriver + 277544
# 3   chromedriver                        0x0000000104a60650 chromedriver + 525904
# 4   chromedriver                        0x0000000104a539cc chromedriver + 473548
# 5   chromedriver                        0x0000000104a531b0 chromedriver + 471472
# 6   chromedriver                        0x0000000104a97618 chromedriver + 751128
# 7   chromedriver                        0x0000000104a518f0 chromedriver + 465136
# 8   chromedriver                        0x0000000104a52974 chromedriver + 469364
# 9   chromedriver                        0x0000000104db7788 chromedriver + 4028296
# ...
